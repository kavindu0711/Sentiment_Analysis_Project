# %%
import numpy as np

# %%
import json
with open ('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'kavindulaxan', 'key': '1c2995b18de9274c513c43c9b3324236'}

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (1.7.4.5)
# Requirement already satisfied: bleach in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (58.0.4)
# Requirement already satisfied: six>=1.10 in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (2.6.2)
# Requirement already satisfied: webencodings in /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages (from kaggle) (0.5.1)

# %%
import os 
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()
# Out:
# /Users/kavindulakshan/Desktop/Sentiment_Analysis_Project/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path = '../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile

with zipfile.ZipFile("../artifacts/sentiment-analysis-dataset.zip", "r") as zip_ref:
    zip_ref.extractall("../artifacts/")
